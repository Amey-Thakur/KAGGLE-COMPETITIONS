# %% [markdown]
# <a href="https://www.kaggle.com/code/ameythakur20/birdclef-2026-tensorflow-2-20-setup?scriptVersionId=306286995" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# [![Kaggle](https://kaggle.com/static/images/open-in-kaggle.svg)](https://www.kaggle.com/code/ameythakur20/birdclef-2026-tensorflow-2-20-setup)
# # BirdCLEF 2026: TensorFlow 2.20 Environment Setup
#
# This notebook configures a **TensorFlow 2.20** environment for the BirdCLEF 2026 competition. It downloads the specific wheel dependencies for the Perch v2 model architectures and utility toolboxes.
#
# - **Competition**: [BirdCLEF+ 2026](https://www.kaggle.com/competitions/birdclef-2026)
# - **Inference Architecture**: [birdclef-2026-perch-v2-bayesian-fusion](https://www.kaggle.com/code/ameythakur20/birdclef-2026-perch-v2-bayesian-fusion)
#
# Author: Amey Thakur (https://www.kaggle.com/ameythakur20)

# %% [markdown]
# # BirdCLEF 2026 Environment: TensorFlow 2.20 Hybrid Setup
#
# This notebook provides a streamlined workflow for configuring a **TensorFlow 2.20** environment within the Kaggle BirdCLEF 2026 competition ecosystem. It addresses the requirement for specific wheel dependencies to support advanced model architectures while maintaining a clean, scholarly structure.
#
# ### **Resources:**
#  - **Competition**: [BirdCLEF+ 2026](https://www.kaggle.com/competitions/birdclef-2026)
#  - **Inference Architecture**: [birdclef-2026-perch-v2-bayesian-fusion](https://www.kaggle.com/code/ameythakur20/birdclef-2026-perch-v2-bayesian-fusion)
#
# **Author**: Amey Thakur (https://www.kaggle.com/ameythakur20)

# %% [markdown]
# ## 1. Environment Configuration
# We begin by initializing the environment and defining paths for dependency management. The primary goal is to fetch and stage the `perch-hoplite` package and its required TensorFlow 2.20 dependencies.

# %%
import os
from pathlib import Path

# Workspace initialization
WHEEL_DIR = Path("wheel")
WHEEL_DIR.mkdir(exist_ok=True)

print(f"Target wheel directory: {WHEEL_DIR.absolute()}")
# Out:
# Target wheel directory: /kaggle/working/wheel

# %% [markdown]
# ## 2. Dependency Resolution
# Using `pip download`, we retrieve the specific versions of TensorFlow and auxiliary libraries required for the Perch v2 inference engine. This creates a portable 'wheelhouse' that can be used for offline installations in competition submissions.

# %%
# Clear previous artifacts and download new dependency tree
# !rm -rf {WHEEL_DIR}
# !mkdir -p {WHEEL_DIR}

print("Starting dependency download for perch-hoplite[tf]...")
# !pip download perch-hoplite[tf] -d {WHEEL_DIR} --quiet

n_wheels = len(list(WHEEL_DIR.glob("*.whl")))
print(f"Successfully staged {n_wheels} wheel files.")
# Out:
# Starting dependency download for perch-hoplite[tf]...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 3.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 4.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 6.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 3.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 3.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.5/117.5 kB 8.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.4/70.4 kB 4.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.6/40.6 kB 2.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.6/79.6 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.5/126.5 kB 8.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## 3. Analysis Summary
# This workflow establishes a foundational environment for BirdCLEF+ 2026. By isolating the TensorFlow 2.20 dependencies, we ensure cross-version compatibility for model serving while bypassing the limitations of the default Kaggle image.
